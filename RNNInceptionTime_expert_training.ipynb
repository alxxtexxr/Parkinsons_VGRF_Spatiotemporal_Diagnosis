# %% [markdown]
# # Libraries

# %%
import os
import numpy as np
import torch
from datetime import datetime
from torch.utils.data import TensorDataset, DataLoader

from src.utils import (
    set_seed, get_device, print_h, 
    eval_window, eval_person_severity_voting, eval_person_majority_voting, eval_person_max_severity, 
    init_metrics, update_metrics, save_metrics_to_json,
)
from src.models.RNNInceptionTime import RNNInceptionTime

# %% [markdown]
# # Config

# %%
k_fold_dir = 'data/preprocessed/Ga_k10_w500_s500_v20250426211229'
seed = 69
set_seed(seed)
device = get_device()
print("Device:", device)

# Training config
batch_size = 8
n_feat = 16
n_class = 4
window_size = 500
lr = 3e-4
n_epoch = 5

run_name_tag = k_fold_dir.split('/')[-1].rsplit('_v', 1)[0] + f'_e{n_epoch}'
print("Run name tag:", run_name_tag)
# Out:
# Random seed: 69
# Device: mps
# Run name tag: Ga_k10_w500_s500_e5

# %% [markdown]
# # Training

# %%
run_name = f'RNNInceptionTime_{run_name_tag+'_' if run_name_tag else ''}v{datetime.now().strftime("%Y%m%d%H%M%S")}'
print("Run name:", run_name)
save_dir = 'checkpoints/' + run_name
os.makedirs(save_dir, exist_ok=True)
print("Save directory:", save_dir)
print()

metrics = {
    'window': init_metrics(['acc', 'f1', 'precision', 'recall', 'cm', 'train_loss', 'val_loss']),
    'person_majority_voting': init_metrics(['acc', 'f1', 'precision', 'recall', 'cm', 'train_loss', 'val_loss']),
    'person_severity_voting': init_metrics(['acc', 'f1', 'precision', 'recall', 'cm', 'train_loss', 'val_loss']),
    'person_max_severity': init_metrics(['acc', 'f1', 'precision', 'recall', 'cm', 'train_loss', 'val_loss']),
}

for i_fold, fold_i_dir_name in enumerate(sorted(os.listdir(k_fold_dir))):
    fold_i_dir = os.path.join(k_fold_dir, fold_i_dir_name)
    print_h(f"FOLD {i_fold+1}", 128)

    # ================================================================================================
    # DATA
    # ================================================================================================
    X_train_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'X_train_window.npy'))).float()
    y_train_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'y_train_window.npy'))).long()

    X_val_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'X_val_window.npy'))).float()
    y_val_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'y_val_window.npy'))).long()

    X_test_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'X_test_window.npy'))).float()
    y_test_window = torch.tensor(np.load(os.path.join(fold_i_dir, f'y_test_window.npy'))).long()

    X_val_person = torch.tensor(np.load(os.path.join(fold_i_dir, f'X_val_person.npy'))).float()
    y_val_person = torch.tensor(np.load(os.path.join(fold_i_dir, f'y_val_person.npy'))).long()

    X_test_person = torch.tensor(np.load(os.path.join(fold_i_dir, f'X_test_person.npy'))).float()
    y_test_person = torch.tensor(np.load(os.path.join(fold_i_dir, f'y_test_person.npy'))).long()

    train_window_dataset = TensorDataset(X_train_window, y_train_window)
    val_window_dataset = TensorDataset(X_val_window, y_val_window)
    test_window_dataset = TensorDataset(X_test_window, y_test_window)
    
    val_person_dataset = TensorDataset(X_val_person, y_val_person)
    test_person_dataset = TensorDataset(X_test_person, y_test_person)

    train_dataloader = DataLoader(train_window_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_window_dataset, batch_size=batch_size, shuffle=False)
    test_dataloader = DataLoader(test_window_dataset, batch_size=batch_size, shuffle=False)
    
    # ================================================================================================
    # TRAINING
    # ================================================================================================
    print_h("TRAINING", 96)

    # Initialize model
    model = RNNInceptionTime(c_in=n_feat, c_out=n_class, seq_len=window_size, bidirectional=True).to(device)

    # Initialize optimizer and loss function
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion =  torch.nn.CrossEntropyLoss()
    
    # Swith the model to training mode
    model.train()
    
    # Loop training epochs
    global_val_loss_window_list = []
    global_val_loss_person_list = []
    global_train_loss_list = []
    train_loss_list = []
    # step = 0
    for epoch in range(n_epoch):
        # Loop training batches
        for iter, (X_train, y_train) in enumerate(train_dataloader):
            # Flush the computed gradients
            optimizer.zero_grad()
            
            X_train = X_train.to(device)
            y_train = y_train.to(device)
            
            # Feed forward the model
            X_train = X_train.permute(0, 2, 1)
            y_pred = model(X_train)

            # Compute training loss
            train_loss = criterion(y_pred, y_train)
            train_loss_list.append(train_loss)
            
            # if (iter+1) % 'step_siz']= 0:
            if iter+1 == len(train_dataloader):
                # ================================================================
                # VALIDATION
                # ================================================================
                avg_val_loss_window, acc_window, f1_window, *_ = eval_window(model, val_dataloader, criterion, average='weighted')
                avg_val_loss_person, acc_person, f1_person, *_ = eval_person_majority_voting(model, test_person_dataset, criterion=criterion, average='weighted',
                                                                                                window_size=window_size)
                
                global_val_loss_window_list.append(avg_val_loss_window)
                global_val_loss_person_list.append(avg_val_loss_person)
                
                # Compute the average training loss for each epoch
                avg_train_loss = sum(train_loss_list) / len(train_dataloader)
                global_train_loss_list.append(avg_train_loss.item())
                train_loss_list = []
                
                # ================================================================
                # LOGGING
                # ================================================================
                print(f"epoch: {epoch+1}, "
                    # f"iter: {iter+1}, "
                    # f"step: {step+1}, "
                    f"train/loss: {avg_train_loss:.3f}, "
                    f"val/loss_window: {avg_val_loss_window:.3f}, "
                    f"val/acc_window: {acc_window:.3f}, "
                    f"val/f1_window: {f1_window:.3f}, "
                    f"val/loss_person: {avg_val_loss_person:.3f}, "
                    f"val/acc_person: {acc_person:.3f}, "
                    f"val/f1_person: {f1_person:.3f}"
                )
                
                # Switch the model back to training mode
                model.train()
                
                # step += 1
            
            # Backward pass the model
            train_loss.backward()
            
            # Update the model weights based on computed gradients
            optimizer.step()
    print()

    # ================================================================================================
    # EVALUATION
    # ================================================================================================
    print_h("EVALUATION", 96)
    
    # ================================================================
    # EVALUATION ON WINDOW DATA
    # ================================================================
    print_h("EVALUATION ON WINDOW DATA", 64)
    (
        _, 
        acc_window, 
        f1_window, 
        precision_window, 
        recall_window, 
        cm_window
    ) = eval_window(
        model, 
        test_dataloader, 
        average='weighted',
    )
    print("acc:", acc_window)
    print("f1:", f1_window)
    print("precision:", precision_window)
    print("recall:", recall_window)
    print("cm:\n", np.array(cm_window))
    print()

    # ================================================================
    # EVALUATION ON PERSON DATA BY MAJORITY VOTING
    # ================================================================
    print_h("EVALUATION ON PERSON DATA BY MAJORITY VOTING", 64)
    (
        _,
        acc_person_majority_voting,
        f1_person_majority_voting,
        precision_person_majority_voting,
        recall_person_majority_voting,
        cm_person_majority_voting,
        *_,
    ) = eval_person_majority_voting(
        model, 
        val_person_dataset, 
        criterion=None, 
        average='weighted',
        window_size=window_size, 
        debug=False,
    )
    print("acc:", acc_person_majority_voting)
    print("f1:", f1_person_majority_voting)
    print("precision:", precision_person_majority_voting)
    print("recall:", recall_person_majority_voting)
    print("cm:\n", np.array(cm_person_majority_voting))
    print()
    
    # ================================================================
    # EVALUATION ON PERSON DATA BY SEVERITY VOTING
    # ================================================================
    print_h("EVALUATION ON PERSON DATA BY SEVERITY VOTING", 64)
    (
        _, 
        acc_person_severity_voting, 
        f1_person_severity_voting, 
        precision_person_severity_voting, 
        recall_person_severity_voting, 
        cm_person_severity_voting,
    ) = eval_person_severity_voting(
        model, 
        val_person_dataset, 
        criterion=None, 
        average='weighted',
        window_size=window_size, 
        debug=False,
    )
    print("acc:", acc_person_severity_voting)
    print("f1:", f1_person_severity_voting)
    print("precision:", precision_person_severity_voting)
    print("recall:", recall_person_severity_voting)
    print("cm:\n", np.array(cm_person_severity_voting))
    print()

    # ================================================================
    # EVALUATION ON PERSON DATA BY MAX. SEVERITY
    # ================================================================
    print_h("EVALUATION ON PERSON DATA BY MAX. SEVERITY", 64)
    (
        _, 
        acc_person_max_severity, 
        f1_person_max_severity, 
        precision_person_max_severity, 
        recall_person_max_severity, 
        cm_person_max_severity,
    ) = eval_person_max_severity(
        model, 
        val_person_dataset, 
        criterion=None, 
        average='weighted',
        window_size=window_size, 
        debug=False,
    )
    print("acc:", acc_person_max_severity)
    print("f1:", f1_person_max_severity)
    print("precision:", precision_person_max_severity)
    print("recall:", recall_person_max_severity)
    print("cm:\n", np.array(cm_person_max_severity))
    print()

    in_metrics = {
        'person_majority_voting': {
            'acc': acc_person_majority_voting,
            'f1': f1_person_majority_voting,
            'precision': precision_person_majority_voting,
            'recall': recall_person_majority_voting,
            'cm': cm_person_majority_voting,
        },
        'person_severity_voting': {
            'acc': acc_person_severity_voting,
            'f1': f1_person_severity_voting,
            'precision': precision_person_severity_voting,
            'recall': recall_person_severity_voting,
            'cm': cm_person_severity_voting,
        },
        'person_max_severity': {
            'acc': acc_person_max_severity,
            'f1': f1_person_max_severity,
            'precision': precision_person_max_severity,
            'recall': recall_person_max_severity,
            'cm': cm_person_max_severity,
        },
        'window': {
            'acc': acc_window,
            'f1': f1_window,
            'precision': precision_window,
            'recall': recall_window,
            'cm': cm_window,
        },
    }

    for metric_type in in_metrics.keys():
        update_metrics(metrics[metric_type], in_metrics[metric_type])

    metrics['window']['train_loss']['folds'].append(global_train_loss_list)
    metrics['window']['val_loss']['folds'].append(global_val_loss_window_list)

    # ================================================================================================
    # CHECKPOINT SAVING
    # ================================================================================================
    save_path = os.path.join(save_dir, f'fold_{i_fold+1}.pth')
    torch.save(model.state_dict(), save_path)
    print(f"Checkpoint for fold {i_fold+1} is saved to:", save_path)
    print()

    # DEBUG: Test for only one fold
    # break

save_metrics_to_json(metrics, save_dir, filename='_evaluation_metrics.json')
print("Evaluation metrics is saved in:", save_dir)
# Out:
# Run name: RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855
# Save directory: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855
#
# ================================================================================================================================
#                                                              FOLD 1
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.690, val/loss_window: 0.366, val/acc_window: 0.901, val/f1_window: 0.897, val/loss_person: 0.511, val/acc_person: 0.938, val/f1_person: 0.930
# epoch: 2, train/loss: 0.404, val/loss_window: 0.176, val/acc_window: 0.955, val/f1_window: 0.956, val/loss_person: 0.396, val/acc_person: 0.938, val/f1_person: 0.929
# epoch: 3, train/loss: 0.255, val/loss_window: 0.133, val/acc_window: 0.973, val/f1_window: 0.973, val/loss_person: 0.655, val/acc_person: 0.812, val/f1_person: 0.760
# epoch: 4, train/loss: 0.211, val/loss_window: 0.122, val/acc_window: 0.957, val/f1_window: 0.957, val/loss_person: 0.556, val/acc_person: 0.875, val/f1_person: 0.820
# epoch: 5, train/loss: 0.168, val/loss_window: 0.060, val/acc_window: 0.982, val/f1_window: 0.982, val/loss_person: 0.531, val/acc_person: 0.875, val/f1_person: 0.821
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9887892376681614
# f1: 0.9887821868742421
# precision: 0.9888446747751614
# recall: 0.9887892376681614
# cm:
#  [[153   0   1   0]
#  [  1 157   1   1]
#  [  0   0 105   0]
#  [  0   1   0  26]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8711538461538462
# precision: 0.8839285714285714
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 2 1]
#  [0 1 0 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8711538461538462
# precision: 0.8839285714285714
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 2 1]
#  [0 1 0 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.875
# f1: 0.8711538461538462
# precision: 0.8839285714285714
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 2 1]
#  [0 1 0 1]]
#
# Checkpoint for fold 1 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_1.pth
#
# ================================================================================================================================
#                                                              FOLD 2
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.723, val/loss_window: 0.349, val/acc_window: 0.915, val/f1_window: 0.908, val/loss_person: 0.722, val/acc_person: 0.750, val/f1_person: 0.710
# epoch: 2, train/loss: 0.389, val/loss_window: 0.136, val/acc_window: 0.980, val/f1_window: 0.980, val/loss_person: 0.487, val/acc_person: 0.938, val/f1_person: 0.941
# epoch: 3, train/loss: 0.251, val/loss_window: 0.091, val/acc_window: 0.982, val/f1_window: 0.982, val/loss_person: 0.581, val/acc_person: 0.938, val/f1_person: 0.941
# epoch: 4, train/loss: 0.196, val/loss_window: 0.148, val/acc_window: 0.944, val/f1_window: 0.943, val/loss_person: 0.481, val/acc_person: 0.875, val/f1_person: 0.877
# epoch: 5, train/loss: 0.147, val/loss_window: 0.047, val/acc_window: 0.996, val/f1_window: 0.996, val/loss_person: 0.761, val/acc_person: 0.875, val/f1_person: 0.887
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9910313901345291
# f1: 0.991026773435554
# precision: 0.9911458195797942
# recall: 0.9910313901345291
# cm:
#  [[154   0   0   0]
#  [  2 158   0   0]
#  [  1   0 104   0]
#  [  0   1   0  26]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 1.0
# f1: 1.0
# precision: 1.0
# recall: 1.0
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.9375
# f1: 0.9364316239316239
# precision: 0.9464285714285714
# recall: 0.9375
# cm:
#  [[4 1 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.9375
# f1: 0.9364316239316239
# precision: 0.9464285714285714
# recall: 0.9375
# cm:
#  [[4 1 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# Checkpoint for fold 2 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_2.pth
#
# ================================================================================================================================
#                                                              FOLD 3
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.668, val/loss_window: 0.332, val/acc_window: 0.908, val/f1_window: 0.900, val/loss_person: 0.759, val/acc_person: 0.750, val/f1_person: 0.699
# epoch: 2, train/loss: 0.368, val/loss_window: 0.186, val/acc_window: 0.942, val/f1_window: 0.941, val/loss_person: 0.505, val/acc_person: 0.812, val/f1_person: 0.807
# epoch: 3, train/loss: 0.266, val/loss_window: 0.096, val/acc_window: 0.982, val/f1_window: 0.982, val/loss_person: 0.463, val/acc_person: 0.938, val/f1_person: 0.941
# epoch: 4, train/loss: 0.215, val/loss_window: 0.069, val/acc_window: 0.982, val/f1_window: 0.982, val/loss_person: 0.310, val/acc_person: 0.938, val/f1_person: 0.941
# epoch: 5, train/loss: 0.176, val/loss_window: 0.047, val/acc_window: 0.984, val/f1_window: 0.984, val/loss_person: 0.527, val/acc_person: 0.875, val/f1_person: 0.887
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9887892376681614
# f1: 0.988643463049605
# precision: 0.9889543041074031
# recall: 0.9887892376681614
# cm:
#  [[153   1   0   0]
#  [  1 159   0   0]
#  [  0   0 105   0]
#  [  0   3   0  24]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.867979242979243
# precision: 0.8995535714285714
# recall: 0.875
# cm:
#  [[4 1 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.8125
# f1: 0.7998511904761905
# precision: 0.859375
# recall: 0.8125
# cm:
#  [[3 2 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.875
# f1: 0.8683035714285714
# precision: 0.90625
# recall: 0.875
# cm:
#  [[3 2 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# Checkpoint for fold 3 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_3.pth
#
# ================================================================================================================================
#                                                              FOLD 4
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.697, val/loss_window: 0.331, val/acc_window: 0.912, val/f1_window: 0.908, val/loss_person: 0.519, val/acc_person: 0.812, val/f1_person: 0.766
# epoch: 2, train/loss: 0.386, val/loss_window: 0.163, val/acc_window: 0.953, val/f1_window: 0.952, val/loss_person: 0.500, val/acc_person: 0.812, val/f1_person: 0.815
# epoch: 3, train/loss: 0.279, val/loss_window: 0.129, val/acc_window: 0.960, val/f1_window: 0.959, val/loss_person: 0.479, val/acc_person: 0.812, val/f1_person: 0.766
# epoch: 4, train/loss: 0.207, val/loss_window: 0.092, val/acc_window: 0.969, val/f1_window: 0.969, val/loss_person: 0.264, val/acc_person: 0.875, val/f1_person: 0.877
# epoch: 5, train/loss: 0.160, val/loss_window: 0.088, val/acc_window: 0.982, val/f1_window: 0.982, val/loss_person: 0.269, val/acc_person: 0.938, val/f1_person: 0.929
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9798206278026906
# f1: 0.9797503380604071
# precision: 0.9806853803490574
# recall: 0.9798206278026906
# cm:
#  [[154   0   0   0]
#  [  2 151   6   1]
#  [  0   0 105   0]
#  [  0   0   0  27]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8193681318681318
# precision: 0.7745535714285714
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 1 1 0]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.8125
# f1: 0.7599206349206349
# precision: 0.734375
# recall: 0.8125
# cm:
#  [[4 1 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 1 1 0]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.8125
# f1: 0.8134920634920635
# precision: 0.828125
# recall: 0.8125
# cm:
#  [[4 1 0 0]
#  [0 5 0 1]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# Checkpoint for fold 4 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_4.pth
#
# ================================================================================================================================
#                                                              FOLD 5
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.728, val/loss_window: 0.343, val/acc_window: 0.897, val/f1_window: 0.891, val/loss_person: 0.587, val/acc_person: 0.812, val/f1_person: 0.761
# epoch: 2, train/loss: 0.407, val/loss_window: 0.217, val/acc_window: 0.957, val/f1_window: 0.957, val/loss_person: 0.344, val/acc_person: 0.875, val/f1_person: 0.870
# epoch: 3, train/loss: 0.288, val/loss_window: 0.200, val/acc_window: 0.946, val/f1_window: 0.946, val/loss_person: 0.321, val/acc_person: 0.875, val/f1_person: 0.866
# epoch: 4, train/loss: 0.233, val/loss_window: 0.119, val/acc_window: 0.975, val/f1_window: 0.975, val/loss_person: 0.060, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 5, train/loss: 0.207, val/loss_window: 0.095, val/acc_window: 0.978, val/f1_window: 0.978, val/loss_person: 0.092, val/acc_person: 1.000, val/f1_person: 1.000
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9932735426008968
# f1: 0.993283249524123
# precision: 0.9934374382584851
# recall: 0.9932735426008968
# cm:
#  [[154   0   0   0]
#  [  0 157   2   1]
#  [  0   0 105   0]
#  [  0   0   0  27]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.9375
# f1: 0.9315476190476191
# precision: 0.953125
# recall: 0.9375
# cm:
#  [[5 0 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8767361111111112
# precision: 0.925
# recall: 0.875
# cm:
#  [[4 0 1 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.75
# f1: 0.7749368686868687
# precision: 0.825
# recall: 0.75
# cm:
#  [[4 0 1 0]
#  [0 5 1 0]
#  [0 0 2 1]
#  [0 0 1 1]]
#
# Checkpoint for fold 5 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_5.pth
#
# ================================================================================================================================
#                                                              FOLD 6
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.668, val/loss_window: 0.443, val/acc_window: 0.834, val/f1_window: 0.819, val/loss_person: 0.680, val/acc_person: 0.812, val/f1_person: 0.756
# epoch: 2, train/loss: 0.364, val/loss_window: 0.157, val/acc_window: 0.978, val/f1_window: 0.978, val/loss_person: 0.611, val/acc_person: 0.875, val/f1_person: 0.872
# epoch: 3, train/loss: 0.269, val/loss_window: 0.119, val/acc_window: 0.978, val/f1_window: 0.978, val/loss_person: 0.458, val/acc_person: 0.938, val/f1_person: 0.930
# epoch: 4, train/loss: 0.216, val/loss_window: 0.111, val/acc_window: 0.964, val/f1_window: 0.964, val/loss_person: 0.462, val/acc_person: 0.938, val/f1_person: 0.930
# epoch: 5, train/loss: 0.143, val/loss_window: 0.084, val/acc_window: 0.971, val/f1_window: 0.972, val/loss_person: 0.378, val/acc_person: 0.938, val/f1_person: 0.930
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9932735426008968
# f1: 0.9932897485618268
# precision: 0.9933814723003649
# recall: 0.9932735426008968
# cm:
#  [[152   2   0   0]
#  [  0 159   0   1]
#  [  0   0 105   0]
#  [  0   0   0  27]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.875
# precision: 0.875
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 5 0 1]
#  [0 0 3 0]
#  [0 1 0 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.6875
# f1: 0.6785714285714286
# precision: 0.7708333333333334
# recall: 0.6875
# cm:
#  [[2 3 0 0]
#  [0 5 0 1]
#  [0 0 3 0]
#  [0 1 0 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.5625
# f1: 0.5808150183150182
# precision: 0.6919642857142857
# recall: 0.5625
# cm:
#  [[2 3 0 0]
#  [0 3 0 3]
#  [0 0 3 0]
#  [0 1 0 1]]
#
# Checkpoint for fold 6 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_6.pth
#
# ================================================================================================================================
#                                                              FOLD 7
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.720, val/loss_window: 0.302, val/acc_window: 0.933, val/f1_window: 0.932, val/loss_person: 0.434, val/acc_person: 0.875, val/f1_person: 0.875
# epoch: 2, train/loss: 0.405, val/loss_window: 0.147, val/acc_window: 0.957, val/f1_window: 0.958, val/loss_person: 0.120, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 3, train/loss: 0.296, val/loss_window: 0.129, val/acc_window: 0.962, val/f1_window: 0.962, val/loss_person: 0.220, val/acc_person: 0.938, val/f1_person: 0.938
# epoch: 4, train/loss: 0.220, val/loss_window: 0.077, val/acc_window: 0.991, val/f1_window: 0.991, val/loss_person: 0.089, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 5, train/loss: 0.167, val/loss_window: 0.052, val/acc_window: 0.989, val/f1_window: 0.989, val/loss_person: 0.051, val/acc_person: 1.000, val/f1_person: 1.000
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9932735426008968
# f1: 0.9933321740492311
# precision: 0.9935972705098339
# recall: 0.9932735426008968
# cm:
#  [[154   0   0   0]
#  [  1 159   0   0]
#  [  0   0 103   2]
#  [  0   0   0  27]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.8125
# f1: 0.8073051948051948
# precision: 0.8385416666666667
# recall: 0.8125
# cm:
#  [[5 0 0 0]
#  [1 4 0 1]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8766233766233765
# precision: 0.890625
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 5 0 1]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.875
# f1: 0.8766233766233765
# precision: 0.890625
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [0 5 0 1]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# Checkpoint for fold 7 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_7.pth
#
# ================================================================================================================================
#                                                              FOLD 8
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.718, val/loss_window: 0.370, val/acc_window: 0.906, val/f1_window: 0.903, val/loss_person: 0.687, val/acc_person: 0.688, val/f1_person: 0.651
# epoch: 2, train/loss: 0.376, val/loss_window: 0.229, val/acc_window: 0.935, val/f1_window: 0.935, val/loss_person: 0.687, val/acc_person: 0.812, val/f1_person: 0.821
# epoch: 3, train/loss: 0.291, val/loss_window: 0.182, val/acc_window: 0.942, val/f1_window: 0.941, val/loss_person: 0.554, val/acc_person: 0.812, val/f1_person: 0.807
# epoch: 4, train/loss: 0.225, val/loss_window: 0.129, val/acc_window: 0.964, val/f1_window: 0.964, val/loss_person: 0.554, val/acc_person: 0.750, val/f1_person: 0.734
# epoch: 5, train/loss: 0.159, val/loss_window: 0.120, val/acc_window: 0.955, val/f1_window: 0.955, val/loss_person: 0.672, val/acc_person: 0.750, val/f1_person: 0.734
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9618834080717489
# f1: 0.9621533572330421
# precision: 0.9650434820301371
# recall: 0.9618834080717489
# cm:
#  [[151   1   2   0]
#  [  0 147  11   2]
#  [  0   0 105   0]
#  [  1   0   0  26]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8698051948051948
# precision: 0.9010416666666667
# recall: 0.875
# cm:
#  [[5 0 0 0]
#  [1 4 1 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.75
# f1: 0.7718750000000001
# precision: 0.8928571428571428
# recall: 0.75
# cm:
#  [[3 0 2 0]
#  [0 4 2 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.75
# f1: 0.7583333333333334
# precision: 0.8625
# recall: 0.75
# cm:
#  [[3 0 1 1]
#  [0 4 1 1]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# Checkpoint for fold 8 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_8.pth
#
# ================================================================================================================================
#                                                              FOLD 9
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.716, val/loss_window: 0.364, val/acc_window: 0.894, val/f1_window: 0.873, val/loss_person: 0.612, val/acc_person: 0.812, val/f1_person: 0.756
# epoch: 2, train/loss: 0.416, val/loss_window: 0.204, val/acc_window: 0.942, val/f1_window: 0.942, val/loss_person: 0.344, val/acc_person: 0.875, val/f1_person: 0.867
# epoch: 3, train/loss: 0.292, val/loss_window: 0.118, val/acc_window: 0.984, val/f1_window: 0.985, val/loss_person: 0.201, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 4, train/loss: 0.232, val/loss_window: 0.079, val/acc_window: 0.980, val/f1_window: 0.979, val/loss_person: 0.090, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 5, train/loss: 0.179, val/loss_window: 0.102, val/acc_window: 0.966, val/f1_window: 0.967, val/loss_person: 0.125, val/acc_person: 1.000, val/f1_person: 1.000
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9551569506726457
# f1: 0.9556045601982585
# precision: 0.9584640335181543
# recall: 0.9551569506726457
# cm:
#  [[142  12   0   0]
#  [  0 157   0   3]
#  [  0   3 102   0]
#  [  0   2   0  25]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.8683035714285714
# precision: 0.90625
# recall: 0.875
# cm:
#  [[3 2 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.8125
# f1: 0.7910714285714286
# precision: 0.875
# recall: 0.8125
# cm:
#  [[2 3 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.8125
# f1: 0.7857142857142856
# precision: 0.859375
# recall: 0.8125
# cm:
#  [[2 2 1 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# Checkpoint for fold 9 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_9.pth
#
# ================================================================================================================================
#                                                             FOLD 10
# ================================================================================================================================
# ================================================================================================
#                                             TRAINING
# ================================================================================================
# epoch: 1, train/loss: 0.683, val/loss_window: 0.290, val/acc_window: 0.901, val/f1_window: 0.874, val/loss_person: 0.585, val/acc_person: 0.688, val/f1_person: 0.665
# epoch: 2, train/loss: 0.398, val/loss_window: 0.254, val/acc_window: 0.908, val/f1_window: 0.906, val/loss_person: 0.392, val/acc_person: 0.875, val/f1_person: 0.868
# epoch: 3, train/loss: 0.267, val/loss_window: 0.120, val/acc_window: 0.960, val/f1_window: 0.959, val/loss_person: 0.285, val/acc_person: 0.875, val/f1_person: 0.868
# epoch: 4, train/loss: 0.227, val/loss_window: 0.066, val/acc_window: 0.989, val/f1_window: 0.989, val/loss_person: 0.115, val/acc_person: 1.000, val/f1_person: 1.000
# epoch: 5, train/loss: 0.184, val/loss_window: 0.057, val/acc_window: 0.989, val/f1_window: 0.989, val/loss_person: 0.178, val/acc_person: 1.000, val/f1_person: 1.000
#
# ================================================================================================
#                                            EVALUATION
# ================================================================================================
# ================================================================
#                    EVALUATION ON WINDOW DATA
# ================================================================
# acc: 0.9775784753363229
# f1: 0.9777652818480325
# precision: 0.9783815065268656
# recall: 0.9775784753363229
# cm:
#  [[151   1   1   1]
#  [  3 154   0   3]
#  [  0   0 105   0]
#  [  0   1   0  26]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY MAJORITY VOTING
# ================================================================
# acc: 0.875
# f1: 0.867979242979243
# precision: 0.8995535714285714
# recall: 0.875
# cm:
#  [[4 1 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#           EVALUATION ON PERSON DATA BY SEVERITY VOTING
# ================================================================
# acc: 0.8125
# f1: 0.7998511904761905
# precision: 0.859375
# recall: 0.8125
# cm:
#  [[3 2 0 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 1 1]]
#
# ================================================================
#            EVALUATION ON PERSON DATA BY MAX. SEVERITY
# ================================================================
# acc: 0.875
# f1: 0.8662431318681318
# precision: 0.8995535714285714
# recall: 0.875
# cm:
#  [[3 1 1 0]
#  [0 6 0 0]
#  [0 0 3 0]
#  [0 0 0 2]]
#
# Checkpoint for fold 10 is saved to: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855/fold_10.pth
#
# Evaluation metrics is saved in: checkpoints/RNNInceptionTime_Ga_k10_w500_s500_e5_v20250429212855
